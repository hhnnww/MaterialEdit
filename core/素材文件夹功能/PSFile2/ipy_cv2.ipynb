# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from pprint import pprint

# %%
im = cv2.imdecode(np.fromfile(r'C:\Users\wuweihua\Desktop\OUT_PATH\1.png', dtype=np.uint8), -1)
print(im.shape)
print(im[0])

plt.figure(figsize=(100, 100))
plt.subplot(121)
plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGRA2RGBA))
plt.show()
# Out:
# (1039, 2185, 4)
# [[255 255 255 255]
#  [255 255 255 255]
#  [255 255 255 255]
#  ...
#  [255 255 255 255]
#  [255 255 255 255]
#  [255 255 255 255]]
